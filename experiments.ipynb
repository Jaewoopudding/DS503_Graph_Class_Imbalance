# %%
import os
import random
import warnings
warnings.filterwarnings(action='ignore')

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn

from torch_geometric.datasets import CoraFull, Planetoid, CitationFull
from torch_geometric.transforms import NormalizeFeatures

from models import GAT, GraphSAGE, GIN
from utils import train_model, test_model, train_constrative_model, valid_model
from mean_average_distance import MAD, MADGap
from virtualnode import VirtualClassNode, UnidirectionalVirtualClassNode

torch.manual_seed(42)
torch.cuda.manual_seed(42)
np.random.seed(42)
random.seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
SAVE_PATH = 'results'
EARLY_STOPPING = 30

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
device
dataset = CitationFull(root='dataset/Cora', name='Cora', transform=NormalizeFeatures())

# %%
data = dataset[0]
df = pd.DataFrame(data.x)
df['y'] = data.y
train, valid = train_test_split(df, stratify=df.y, test_size=0.4)
valid, test = train_test_split(valid, stratify=valid.y, test_size=0.5)
data.train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
data.train_mask[train.index]=True
data.valid_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
data.valid_mask[valid.index]=True
data.test_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
data.test_mask[test.index]=True

# %%
mad = MAD(device=device, global_flag=True)
madgap = MADGap(device, 3, 8)

# %%
hyperparameters = {
    'virtualnode' : [UnidirectionalVirtualClassNode(), VirtualClassNode()],
    'temperature' : np.linspace(0.1, 1, num=10),
    'constrative_coef' : np.logspace(-4, -1, 6),
    'lr': np.logspace(-4, -2, 5)
}

tuning_result = pd.DataFrame({
                            'model' : [],
                            'virtualnode' : [],
                            'temperature' : [],
                            'constrative coef' : [],
                            'lr' : [],
                            'train_acc' : [],
                            'train_loss' : [],
                            'val_acc' : [],
                            'val_loss' : [],
                            'test_acc' : [],
                            'macro f1' : [],
                            'micro f1'
                            'minor f1' : [],
                            'mad' : [],
                            'madgap' : []                            
                            })

# %%
for virtualnode in hyperparameters['virtualnode']:
    if virtualnode is None:
        vc = 'None'
        data_for_tuning = data
        constrative_flag = False
    else:
        vc = virtualnode
        data_for_tuning = vc.forward(data)
        constrative_flag = True
        
    for temperature in hyperparameters['temperature']:
        for constrative_coef in hyperparameters['constrative_coef']:
            for lr in hyperparameters['lr']:
                models = [GraphSAGE(in_channels=dataset.num_features, hidden_channels=256, number_of_classes=dataset.num_classes, num_of_hidden_layers=4, device=device)]
                for model in models:
                    print(f'VC : {vc}, temp : {temperature:.5f}, constrative coef : {constrative_coef:.5f}, lr : {lr:.5f} ')
                    max_loss = 10000
                    early_stopping_count = 0
                    print(f'Model: {model.name} | Number of parameters: {model.get_n_params()}')
                    model = model.to(device)
                    data_for_tuning = data_for_tuning.to(device)
                    criterion = nn.CrossEntropyLoss()
                    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=5e-4)
                    losses = []
                    accs = []
                    val_losses = []
                    val_accs = []
                    for epoch in range(5000):
                        loss, acc = train_constrative_model(model, data_for_tuning, optimizer, criterion, cnode_weight=2,
                                                            constrative_coef=constrative_coef, temperature=temperature, positive_sampling=True)
                        losses.append(loss.item())
                        accs.append(100*acc)
                        val_loss, val_acc = valid_model(model, data_for_tuning, criterion, cnode_weight=2,
                                                        constrative_coef=constrative_coef, temperature=temperature, positive_sampling=True)
                        val_accs.append(100*val_acc)
                        if val_loss < max_loss:
                            max_loss = val_loss
                            early_stopping_count = 0
                        else:
                            early_stopping_count += 1
                            if early_stopping_count > EARLY_STOPPING:
                                print("Early stopping..")
                                break
                        if epoch%10==0:
                            print(f'Epoch: {epoch:03d}, Train Loss: {loss:.4f}, Train Acc: {100*acc:.2f}, Valid Loss: {val_loss:.4f}, Valid Acc: {100*val_acc:.2f}')
                        if epoch > 500:
                            if val_acc < 0.1:
                                print('underfitting...')
                                break
                    report = test_model(model, data_for_tuning)
                    result = pd.DataFrame(report).T
                    result_sliced = result.iloc[:-3 if len(result) < 23 else 20, :]
                    test_acc = result.loc['accuracy'][0]
                    result.loc['minorities-f1',:] = result_sliced.mean(axis=0)
                    result.to_csv(os.path.join(SAVE_PATH, f'{model.name}_layers{model.num_of_hidden_layers}_neurons{model.hidden_channels}'+'.csv'))
                    result = model(data_for_tuning.x.to(device), data_for_tuning.edge_index.to(device))[0].cpu()
                    global_mad = mad(result).item()
                    mad_gap = madgap(result, data_for_tuning.edge_index).item()
                    
                    exp_result_dict = {
                        'model' : model.name,
                        'virtualnode' : vc,
                        'temperature' : temperature,
                        'constrative coef' : constrative_coef,
                        'lr' : lr,
                        'train_acc' : acc,
                        'train_loss' : loss,
                        'val_acc' : val_acc,
                        'val_loss' : val_loss,
                        'test_acc' : test_acc,
                        'macro f1' : pd.DataFrame(report).T.loc['macro avg', 'f1-score'],
                        'micro f1' : pd.DataFrame(report).T.loc['weighted avg', 'f1-score'],
                        'minor f1' : pd.DataFrame(report).T[:-3].sort_values(by='support', ascending=False)[-11:].mean()['f1-score'],
                        'mad' : global_mad,
                        'madgap' : mad_gap                            
                    }
                    
                    tuning_result = tuning_result.append(exp_result_dict, ignore_index=True)
                    
                    print(f'global_mad: {global_mad}')
                    print(f'madgap: {mad_gap}')
                    print(f'Test Acc: {100*test_acc}')
                    
                    print('==========================================', end='\n\n')
                    del model
                    torch.cuda.empty_cache()   
                    
    del data_for_tuning     
    torch.cuda.empty_cache()
# Out:
# VC : UnidirectionalVirtualClassNode(), temp : 0.10000, constrative coef : 0.00010, lr : 0.00010
# Model: GraphSAGE | Number of parameters: 4853760
# Epoch: 000, Train Loss: 8.5466, Train Acc: 1.00, Valid Loss: 8.5662, Valid Acc: 0.79
# Epoch: 010, Train Loss: 8.5278, Train Acc: 3.57, Valid Loss: 8.5501, Valid Acc: 3.92
# Epoch: 020, Train Loss: 8.5068, Train Acc: 4.07, Valid Loss: 8.5387, Valid Acc: 4.64
# Epoch: 030, Train Loss: 8.4984, Train Acc: 4.65, Valid Loss: 8.5324, Valid Acc: 4.64
# Epoch: 040, Train Loss: 8.4842, Train Acc: 4.56, Valid Loss: 8.5284, Valid Acc: 4.64
# Epoch: 050, Train Loss: 8.4786, Train Acc: 4.52, Valid Loss: 8.5225, Valid Acc: 4.64
# Epoch: 060, Train Loss: 8.4737, Train Acc: 4.59, Valid Loss: 8.5099, Valid Acc: 4.64
# Epoch: 070, Train Loss: 8.4458, Train Acc: 4.86, Valid Loss: 8.4857, Valid Acc: 4.64
# Epoch: 080, Train Loss: 8.4262, Train Acc: 4.99, Valid Loss: 8.4504, Valid Acc: 4.64
# Epoch: 090, Train Loss: 8.4085, Train Acc: 4.68, Valid Loss: 8.4262, Valid Acc: 4.64
# Epoch: 100, Train Loss: 8.3961, Train Acc: 4.94, Valid Loss: 8.4132, Valid Acc: 4.64
# Epoch: 110, Train Loss: 8.3933, Train Acc: 5.15, Valid Loss: 8.3996, Valid Acc: 4.64
# Epoch: 120, Train Loss: 8.3709, Train Acc: 5.06, Valid Loss: 8.3789, Valid Acc: 4.64
# Epoch: 130, Train Loss: 8.3365, Train Acc: 5.18, Valid Loss: 8.3438, Valid Acc: 6.28
# Epoch: 140, Train Loss: 8.2671, Train Acc: 5.68, Valid Loss: 8.2748, Valid Acc: 7.84
# Epoch: 150, Train Loss: 8.1414, Train Acc: 8.89, Valid Loss: 8.1153, Valid Acc: 8.89
# Epoch: 160, Train Loss: 7.8427, Train Acc: 8.66, Valid Loss: 7.7958, Valid Acc: 8.56
# Epoch: 170, Train Loss: 7.4851, Train Acc: 6.86, Valid Loss: 7.4538, Valid Acc: 5.71
# Epoch: 180, Train Loss: 7.2026, Train Acc: 8.74, Valid Loss: 7.1658, Valid Acc: 10.55
# Epoch: 190, Train Loss: 6.9769, Train Acc: 9.75, Valid Loss: 6.9213, Valid Acc: 10.72
# Epoch: 200, Train Loss: 6.7215, Train Acc: 12.42, Valid Loss: 6.6601, Valid Acc: 13.58
# Epoch: 210, Train Loss: 6.4223, Train Acc: 15.04, Valid Loss: 6.3370, Valid Acc: 18.27
# Epoch: 220, Train Loss: 6.0696, Train Acc: 17.36, Valid Loss: 5.9861, Valid Acc: 19.09
# Epoch: 230, Train Loss: 5.7398, Train Acc: 20.36, Valid Loss: 5.6652, Valid Acc: 21.89
# Epoch: 240, Train Loss: 5.4604, Train Acc: 22.13, Valid Loss: 5.3765, Valid Acc: 24.77
# Epoch: 250, Train Loss: 5.2306, Train Acc: 23.86, Valid Loss: 5.1181, Valid Acc: 27.13
# Epoch: 260, Train Loss: 5.0064, Train Acc: 25.47, Valid Loss: 4.8851, Valid Acc: 29.36
# Epoch: 270, Train Loss: 4.8596, Train Acc: 27.17, Valid Loss: 4.6806, Valid Acc: 30.88
# Epoch: 280, Train Loss: 4.6718, Train Acc: 28.77, Valid Loss: 4.5008, Valid Acc: 32.79
# Epoch: 290, Train Loss: 4.4788, Train Acc: 29.71, Valid Loss: 4.3428, Valid Acc: 34.03
# Epoch: 300, Train Loss: 4.3676, Train Acc: 31.08, Valid Loss: 4.1989, Valid Acc: 35.59
# Epoch: 310, Train Loss: 4.2762, Train Acc: 32.01, Valid Loss: 4.0680, Valid Acc: 35.91
# Epoch: 320, Train Loss: 4.1974, Train Acc: 32.31, Valid Loss: 3.9462, Valid Acc: 37.16
# Epoch: 330, Train Loss: 4.0496, Train Acc: 33.94, Valid Loss: 3.8312, Valid Acc: 38.72
# Epoch: 340, Train Loss: 3.9885, Train Acc: 36.19, Valid Loss: 3.7163, Valid Acc: 40.21
# Epoch: 350, Train Loss: 3.8198, Train Acc: 37.33, Valid Loss: 3.6029, Valid Acc: 41.72
# Epoch: 360, Train Loss: 3.7380, Train Acc: 39.52, Valid Loss: 3.4883, Valid Acc: 43.56
# Epoch: 370, Train Loss: 3.6074, Train Acc: 40.04, Valid Loss: 3.3654, Valid Acc: 44.95
# Epoch: 380, Train Loss: 3.4941, Train Acc: 42.03, Valid Loss: 3.2401, Valid Acc: 46.74
# Epoch: 390, Train Loss: 3.3631, Train Acc: 43.80, Valid Loss: 3.1133, Valid Acc: 47.41
# Epoch: 400, Train Loss: 3.2455, Train Acc: 45.01, Valid Loss: 2.9918, Valid Acc: 48.95
# Epoch: 410, Train Loss: 3.1399, Train Acc: 46.55, Valid Loss: 2.8722, Valid Acc: 49.32
# Epoch: 420, Train Loss: 3.0342, Train Acc: 47.53, Valid Loss: 2.7631, Valid Acc: 50.36
# Epoch: 430, Train Loss: 2.8818, Train Acc: 48.44, Valid Loss: 2.6655, Valid Acc: 51.25
# Epoch: 440, Train Loss: 2.8337, Train Acc: 49.02, Valid Loss: 2.5705, Valid Acc: 52.54
# Epoch: 450, Train Loss: 2.7700, Train Acc: 50.79, Valid Loss: 2.4868, Valid Acc: 53.14
# Epoch: 460, Train Loss: 2.6558, Train Acc: 51.09, Valid Loss: 2.4128, Valid Acc: 53.83
# Epoch: 470, Train Loss: 2.6028, Train Acc: 51.59, Valid Loss: 2.3465, Valid Acc: 54.16
# Epoch: 480, Train Loss: 2.5435, Train Acc: 52.59, Valid Loss: 2.2838, Valid Acc: 54.53
# Epoch: 490, Train Loss: 2.5018, Train Acc: 52.44, Valid Loss: 2.2244, Valid Acc: 54.75
# Epoch: 500, Train Loss: 2.4354, Train Acc: 53.58, Valid Loss: 2.1707, Valid Acc: 55.25
# Epoch: 510, Train Loss: 2.4052, Train Acc: 54.18, Valid Loss: 2.1196, Valid Acc: 56.04
# Epoch: 520, Train Loss: 2.3308, Train Acc: 55.20, Valid Loss: 2.0682, Valid Acc: 55.94
# Epoch: 530, Train Loss: 2.2596, Train Acc: 55.90, Valid Loss: 2.0198, Valid Acc: 56.47
# Epoch: 540, Train Loss: 2.2492, Train Acc: 55.40, Valid Loss: 1.9759, Valid Acc: 56.59
# Epoch: 550, Train Loss: 2.2120, Train Acc: 56.35, Valid Loss: 1.9313, Valid Acc: 57.51
# Epoch: 560, Train Loss: 2.1359, Train Acc: 57.15, Valid Loss: 1.8899, Valid Acc: 57.58
# Epoch: 570, Train Loss: 2.1115, Train Acc: 57.31, Valid Loss: 1.8515, Valid Acc: 57.93
# Epoch: 580, Train Loss: 2.0702, Train Acc: 58.57, Valid Loss: 1.8117, Valid Acc: 58.20
# Epoch: 590, Train Loss: 2.0538, Train Acc: 58.48, Valid Loss: 1.7735, Valid Acc: 58.92
# Epoch: 600, Train Loss: 2.0068, Train Acc: 58.96, Valid Loss: 1.7386, Valid Acc: 59.20
# Epoch: 610, Train Loss: 1.9704, Train Acc: 59.59, Valid Loss: 1.7054, Valid Acc: 59.54
# Epoch: 620, Train Loss: 1.9564, Train Acc: 59.35, Valid Loss: 1.6735, Valid Acc: 59.39
# Epoch: 630, Train Loss: 1.9117, Train Acc: 59.67, Valid Loss: 1.6430, Valid Acc: 59.77
# Epoch: 640, Train Loss: 1.8783, Train Acc: 60.28, Valid Loss: 1.6138, Valid Acc: 60.14
# Epoch: 650, Train Loss: 1.8412, Train Acc: 61.21, Valid Loss: 1.5862, Valid Acc: 60.69
# Epoch: 660, Train Loss: 1.8229, Train Acc: 61.23, Valid Loss: 1.5604, Valid Acc: 61.13
# Epoch: 670, Train Loss: 1.7803, Train Acc: 61.70, Valid Loss: 1.5366, Valid Acc: 61.23
# Epoch: 680, Train Loss: 1.7412, Train Acc: 62.58, Valid Loss: 1.5111, Valid Acc: 61.65
# Epoch: 690, Train Loss: 1.7482, Train Acc: 63.01, Valid Loss: 1.4869, Valid Acc: 61.48
# Epoch: 700, Train Loss: 1.7148, Train Acc: 62.54, Valid Loss: 1.4656, Valid Acc: 61.65
# Epoch: 710, Train Loss: 1.7029, Train Acc: 62.99, Valid Loss: 1.4452, Valid Acc: 61.80
# Epoch: 720, Train Loss: 1.6837, Train Acc: 63.05, Valid Loss: 1.4248, Valid Acc: 62.20
# Epoch: 730, Train Loss: 1.6553, Train Acc: 63.42, Valid Loss: 1.4055, Valid Acc: 62.52
# Epoch: 740, Train Loss: 1.6239, Train Acc: 64.05, Valid Loss: 1.3862, Valid Acc: 62.40
# Epoch: 750, Train Loss: 1.6078, Train Acc: 64.32, Valid Loss: 1.3684, Valid Acc: 62.62
# Epoch: 760, Train Loss: 1.5883, Train Acc: 63.90, Valid Loss: 1.3516, Valid Acc: 62.55
# Epoch: 770, Train Loss: 1.5721, Train Acc: 65.25, Valid Loss: 1.3333, Valid Acc: 62.87
# Epoch: 780, Train Loss: 1.5637, Train Acc: 64.75, Valid Loss: 1.3182, Valid Acc: 62.94
# Epoch: 790, Train Loss: 1.5501, Train Acc: 65.01, Valid Loss: 1.3011, Valid Acc: 62.97
# Epoch: 800, Train Loss: 1.5310, Train Acc: 65.15, Valid Loss: 1.2873, Valid Acc: 62.99
# Epoch: 810, Train Loss: 1.5241, Train Acc: 65.12, Valid Loss: 1.2705, Valid Acc: 63.22
# Epoch: 820, Train Loss: 1.4993, Train Acc: 65.63, Valid Loss: 1.2565, Valid Acc: 63.42
# Epoch: 830, Train Loss: 1.4811, Train Acc: 65.91, Valid Loss: 1.2435, Valid Acc: 63.54
# Epoch: 840, Train Loss: 1.4684, Train Acc: 65.47, Valid Loss: 1.2288, Valid Acc: 63.81
# Epoch: 850, Train Loss: 1.4698, Train Acc: 65.87, Valid Loss: 1.2182, Valid Acc: 63.91
# Epoch: 860, Train Loss: 1.4493, Train Acc: 66.55, Valid Loss: 1.2031, Valid Acc: 63.84
# Epoch: 870, Train Loss: 1.4384, Train Acc: 66.52, Valid Loss: 1.1890, Valid Acc: 64.06
# Epoch: 880, Train Loss: 1.4241, Train Acc: 66.79, Valid Loss: 1.1764, Valid Acc: 64.31
# Epoch: 890, Train Loss: 1.4078, Train Acc: 66.97, Valid Loss: 1.1643, Valid Acc: 64.36
# Epoch: 900, Train Loss: 1.4014, Train Acc: 67.09, Valid Loss: 1.1526, Valid Acc: 64.38
# Epoch: 910, Train Loss: 1.3905, Train Acc: 66.97, Valid Loss: 1.1412, Valid Acc: 64.41
# Epoch: 920, Train Loss: 1.3748, Train Acc: 66.80, Valid Loss: 1.1297, Valid Acc: 64.48
# Epoch: 930, Train Loss: 1.3428, Train Acc: 67.94, Valid Loss: 1.1180, Valid Acc: 64.68
# Epoch: 940, Train Loss: 1.3702, Train Acc: 67.73, Valid Loss: 1.1074, Valid Acc: 64.68
# Epoch: 950, Train Loss: 1.3347, Train Acc: 67.71, Valid Loss: 1.0964, Valid Acc: 64.90
# Epoch: 960, Train Loss: 1.3263, Train Acc: 67.87, Valid Loss: 1.0857, Valid Acc: 64.71
# Epoch: 970, Train Loss: 1.3224, Train Acc: 68.34, Valid Loss: 1.0760, Valid Acc: 64.78
# Epoch: 980, Train Loss: 1.3083, Train Acc: 68.55, Valid Loss: 1.0648, Valid Acc: 64.66
# Epoch: 990, Train Loss: 1.3092, Train Acc: 68.12, Valid Loss: 1.0544, Valid Acc: 64.98
# Epoch: 1000, Train Loss: 1.3142, Train Acc: 68.10, Valid Loss: 1.0451, Valid Acc: 64.85
# Epoch: 1010, Train Loss: 1.2716, Train Acc: 68.85, Valid Loss: 1.0357, Valid Acc: 64.68
# Epoch: 1020, Train Loss: 1.2658, Train Acc: 68.78, Valid Loss: 1.0272, Valid Acc: 65.03
# Epoch: 1030, Train Loss: 1.2627, Train Acc: 69.10, Valid Loss: 1.0181, Valid Acc: 64.90
# Epoch: 1040, Train Loss: 1.2490, Train Acc: 69.59, Valid Loss: 1.0093, Valid Acc: 64.98
# Epoch: 1050, Train Loss: 1.2379, Train Acc: 69.87, Valid Loss: 0.9992, Valid Acc: 65.23
# Epoch: 1060, Train Loss: 1.2404, Train Acc: 69.31, Valid Loss: 0.9899, Valid Acc: 65.15
# Epoch: 1070, Train Loss: 1.2192, Train Acc: 69.32, Valid Loss: 0.9812, Valid Acc: 65.20
# Epoch: 1080, Train Loss: 1.2023, Train Acc: 70.36, Valid Loss: 0.9746, Valid Acc: 65.25
# Epoch: 1090, Train Loss: 1.2000, Train Acc: 70.10, Valid Loss: 0.9647, Valid Acc: 65.28
# Epoch: 1100, Train Loss: 1.2049, Train Acc: 70.11, Valid Loss: 0.9571, Valid Acc: 65.38
# Epoch: 1110, Train Loss: 1.2024, Train Acc: 69.74, Valid Loss: 0.9496, Valid Acc: 65.13
# Epoch: 1120, Train Loss: 1.1878, Train Acc: 70.37, Valid Loss: 0.9420, Valid Acc: 65.28
# Epoch: 1130, Train Loss: 1.1810, Train Acc: 70.13, Valid Loss: 0.9336, Valid Acc: 65.40
# Epoch: 1140, Train Loss: 1.1866, Train Acc: 70.36, Valid Loss: 0.9265, Valid Acc: 65.43
# Epoch: 1150, Train Loss: 1.1809, Train Acc: 70.31, Valid Loss: 0.9191, Valid Acc: 65.43
# Epoch: 1160, Train Loss: 1.1619, Train Acc: 71.19, Valid Loss: 0.9111, Valid Acc: 65.45
# Epoch: 1170, Train Loss: 1.1533, Train Acc: 70.60, Valid Loss: 0.9046, Valid Acc: 65.60
# Epoch: 1180, Train Loss: 1.1513, Train Acc: 70.72, Valid Loss: 0.8968, Valid Acc: 65.55
# Epoch: 1190, Train Loss: 1.1273, Train Acc: 70.93, Valid Loss: 0.8904, Valid Acc: 65.70
# Epoch: 1200, Train Loss: 1.1325, Train Acc: 71.11, Valid Loss: 0.8841, Valid Acc: 65.67
# Epoch: 1210, Train Loss: 1.1341, Train Acc: 71.08, Valid Loss: 0.8764, Valid Acc: 65.87
# Epoch: 1220, Train Loss: 1.1264, Train Acc: 70.97, Valid Loss: 0.8706, Valid Acc: 65.70
# Epoch: 1230, Train Loss: 1.1021, Train Acc: 71.96, Valid Loss: 0.8645, Valid Acc: 65.75
# Epoch: 1240, Train Loss: 1.1207, Train Acc: 71.13, Valid Loss: 0.8583, Valid Acc: 65.80
# Epoch: 1250, Train Loss: 1.1040, Train Acc: 71.88, Valid Loss: 0.8512, Valid Acc: 66.10
# Epoch: 1260, Train Loss: 1.0909, Train Acc: 71.91, Valid Loss: 0.8454, Valid Acc: 66.05
# Epoch: 1270, Train Loss: 1.1067, Train Acc: 71.57, Valid Loss: 0.8384, Valid Acc: 66.44
# Epoch: 1280, Train Loss: 1.0827, Train Acc: 71.58, Valid Loss: 0.8320, Valid Acc: 66.34

# %%
tuning_result.to_csv('tuning result', index=False)
